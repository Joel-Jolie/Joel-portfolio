# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\Joela\\Downloads\\pride_events.csv")

# %%
print(df)
# Out:
#           location  start_date    end_date               description  \
# 0            Miami  11/22/2006  11/27/2006          White Party Week
# 1            Aspen   1/14/2007   1/21/2007  Gay and Lesbian Ski Week
# 2            Miami   1/28/2007    2/4/2007  Freedom Caribbean Cruise
# 3            Miami   2/28/2007    3/5/2007              Winter Party
# 4          Orlando   5/29/2007    6/4/2007  Gay Days Reunion Weekend
# ..             ...         ...         ...                       ...
# 764       Key West    6/7/2023   6/11/2023            Key West Pride
# 765         Denver   6/24/2023   6/25/2023     Gay Pride Fest Denver
# 766  San Francisco   6/24/2023   6/25/2023       San Francisco Pride
# 767        Seattle   6/24/2023   6/25/2023             Seattle Pride
# 768    Los Angeles   9/22/2023   9/24/2023          Gay Days Anaheim
#
#      USA for sure       timestamp
# 0               0  20061026221710
# 1               0  20070114195410
# 2               0  20070125091636
# 3               0  20070206002150
# 4               0  20070125091636
# ..            ...             ...
# 764             1  20230110021932
# 765             1  20230110021932
# 766             1  20230110021932
# 767             1  20230110021932
# 768             1  20230110021932
#
# [769 rows x 6 columns]

# %%
df
# Out:
#           location  start_date    end_date               description  \
# 0            Miami  11/22/2006  11/27/2006          White Party Week
# 1            Aspen   1/14/2007   1/21/2007  Gay and Lesbian Ski Week
# 2            Miami   1/28/2007    2/4/2007  Freedom Caribbean Cruise
# 3            Miami   2/28/2007    3/5/2007              Winter Party
# 4          Orlando   5/29/2007    6/4/2007  Gay Days Reunion Weekend
# ..             ...         ...         ...                       ...
# 764       Key West    6/7/2023   6/11/2023            Key West Pride
# 765         Denver   6/24/2023   6/25/2023     Gay Pride Fest Denver
# 766  San Francisco   6/24/2023   6/25/2023       San Francisco Pride
# 767        Seattle   6/24/2023   6/25/2023             Seattle Pride
# 768    Los Angeles   9/22/2023   9/24/2023          Gay Days Anaheim
#
#      USA for sure       timestamp
# 0               0  20061026221710
# 1               0  20070114195410
# 2               0  20070125091636
# 3               0  20070206002150
# 4               0  20070125091636
# ..            ...             ...
# 764             1  20230110021932
# 765             1  20230110021932
# 766             1  20230110021932
# 767             1  20230110021932
# 768             1  20230110021932
#
# [769 rows x 6 columns]

# %%
no_cols = len(df.columns)
no_rows = len(df)

# %%
print(f'We have {no_cols} columns.')
print(f'We have {no_rows} rows.')
# Out:
# We have 6 columns.
# We have 769 rows.

# %%
df.columns
# Out:
# Index(['location', 'start_date', 'end_date', 'description', 'USA for sure',
#        'timestamp'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 769 entries, 0 to 768
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   location      769 non-null    object
#  1   start_date    769 non-null    object
#  2   end_date      769 non-null    object
#  3   description   769 non-null    object
#  4   USA for sure  769 non-null    int64
#  5   timestamp     769 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 36.2+ KB

# %%
df.sample(10)
# Out:
#             location  start_date    end_date                     description  \
# 412          Seattle    8/1/2015    8/8/2015          RSVP gay Alaska cruise
# 586      New Orleans    6/8/2018   6/10/2018           Gay Pride New Orleans
# 148         New York   3/23/2012   3/24/2012                 The Black Party
# 608           Austin   8/25/2018   8/25/2018                Austin Gay Pride
# 686          Orlando  10/12/2019  10/12/2019                   Orlando Pride
# 442    Mammoth Lakes   3/16/2016   3/20/2016  Elevation Mammoth gay ski week
# 463      Los Angeles   6/10/2016   6/12/2016               Los Angeles Pride
# 621        Las Vegas  10/19/2018  10/21/2018                 Las Vegas Pride
# 510  Fort Lauderdale   2/26/2017   2/26/2017           Pride Fort Lauderdale
# 337         New York   7/18/2014   7/20/2014              Sand Blast Weekend
#
#      USA for sure       timestamp
# 412             1  20150801025925
# 586             1  20180620225535
# 148             1  20120314160457
# 608             1  20180620225535
# 686             1  20190911024932
# 442             1  20160314101730
# 463             1  20160610154341
# 621             1  20180620225535
# 510             1  20170216000808
# 337             1  20140625131713

# %%
df.head(10)
# Out:
#         location  start_date    end_date                  description  \
# 0          Miami  11/22/2006  11/27/2006             White Party Week
# 1          Aspen   1/14/2007   1/21/2007     Gay and Lesbian Ski Week
# 2          Miami   1/28/2007    2/4/2007     Freedom Caribbean Cruise
# 3          Miami   2/28/2007    3/5/2007                 Winter Party
# 4        Orlando   5/29/2007    6/4/2007     Gay Days Reunion Weekend
# 5        Orlando   5/29/2007   5/29/2007  Gay Days One Mighty Weekend
# 6       New York   6/17/2007   6/24/2007                NYC Gay Pride
# 7  San Francisco   6/23/2007   6/24/2007          San Francisco Pride
# 8  San Francisco   9/30/2007   9/30/2007           Folsom Street Fair
# 9          Miami  11/21/2007  11/26/2007             White Party Week
#
#    USA for sure       timestamp
# 0             0  20061026221710
# 1             0  20070114195410
# 2             0  20070125091636
# 3             0  20070206002150
# 4             0  20070125091636
# 5             0  20070518172714
# 6             0  20070518172714
# 7             0  20070518172714
# 8             0  20070925160559
# 9             0  20071117111838

# %%
df.tail(10)
# Out:
#           location start_date   end_date               description  \
# 759      Cleveland   4/6/2023   4/9/2023    Claw Leather Awareness
# 760          Miami  4/15/2023  4/16/2023     Miami Beach gay pride
# 761   Palm Springs  5/12/2023  5/14/2023  White Party Palm Springs
# 762         Dallas   6/3/2023   6/4/2023      Dallas Pride Weekend
# 763      Oceanside   6/3/2023   6/3/2023        Pride by the beach
# 764       Key West   6/7/2023  6/11/2023            Key West Pride
# 765         Denver  6/24/2023  6/25/2023     Gay Pride Fest Denver
# 766  San Francisco  6/24/2023  6/25/2023       San Francisco Pride
# 767        Seattle  6/24/2023  6/25/2023             Seattle Pride
# 768    Los Angeles  9/22/2023  9/24/2023          Gay Days Anaheim
#
#      USA for sure       timestamp
# 759             1  20230110021932
# 760             1  20230110021932
# 761             1  20230110021932
# 762             1  20230110021932
# 763             1  20230110021932
# 764             1  20230110021932
# 765             1  20230110021932
# 766             1  20230110021932
# 767             1  20230110021932
# 768             1  20230110021932

# %%
name_freq = df['location'].value_counts()

# %%
name_freq
# Out:
# location
# Miami                62
# Los Angeles          61
# New York             56
# New Orleans          49
# Orlando              46
# San Francisco        46
# Chicago              36
# Washington D.C       36
# Fort Lauderdale      35
# Provincetown         31
# Palm Springs         31
# Las Vegas            27
# Dallas               23
# Cleveland            20
# Key West             18
# Aspen                16
# Austin               16
# San Diego            15
# Seattle              15
# Honolulu             13
# Mammoth Lakes        11
# Boston               10
# Black Rock Desert     9
# Portland              9
# Houston               9
# Atlanta               9
# Oceanside             9
# Detroit               8
# Philadelphia          8
# Denver                8
# Minneapolis           7
# Phoenix               6
# Providence            6
# Pensacola             4
# Tampa                 2
# Oakland               1
# Anaheim               1
# Name: count, dtype: int64

# %%
name_freq[0:20].plot(kind='bar')
# Out:
# <Axes: xlabel='location'>
